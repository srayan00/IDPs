# %%
import pandas as pd
import numpy as np
import os
import sys
import gzip
import shutil
import json
import re
import argparse
import Bio.PDB as bpdb
from Bio import Align
import requests

# %%
# response = requests.get("https://www.ebi.ac.uk:443/interpro/api/entry/all/protein/UniProt/P05067/")
response = requests.get("https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/UniProt/P13671/")
# response = requests.get("https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/UniProt/P01031/")

# %%
json_file = response.json()["results"]
print(json_file[0]["metadata"])
# Out:
# {'accession': 'IPR000436', 'name': 'Sushi/SCR/CCP domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'profile': {'PS50923': 'Sushi/CCP/SCR domain profile'}, 'cdd': {'cd00033': 'Complement control protein (CCP) modules (aka short consensus repeats SCRs or SUSHI repeats) have been identified in several proteins of the complement system'}, 'smart': {'SM00032': 'Domain abundant in complement control proteins; SUSHI repeat; short complement-like repeat (SCR)'}, 'pfam': {'PF00084': 'Sushi repeat (SCR repeat)'}}, 'go_terms': None}

# %%
print(json.dumps(json_file, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "metadata": {
#             "accession": "IPR000436",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "cdd": {
#                     "cd00033": "Complement control protein (CCP) modules (aka short consensus repeats SCRs or SUSHI repeats) have been identified in several proteins of the complement system"
#                 },
#                 "pfam": {
#                     "PF00084": "Sushi repeat (SCR repeat)"
#                 },
#                 "profile": {
#                     "PS50923": "Sushi/CCP/SCR domain profile"
#                 },
#                 "smart": {
#                     "SM00032": "Domain abundant in complement control proteins; SUSHI repeat; short complement-like repeat (SCR)"
#                 }
#             },
#             "name": "Sushi/SCR/CCP domain",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 701,
#                                 "representative": false,
#                                 "start": 642
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 763,
#                                 "representative": false,
#                                 "start": 702
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR000884",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "pfam": {
#                     "PF00090": "Thrombospondin type 1 domain"
#                 },
#                 "profile": {
#                     "PS50092": "Thrombospondin type-1 (TSP1) repeat profile"
#                 },
#                 "smart": {
#                     "SM00209": "Thrombospondin type 1 repeats"
#                 }
#             },
#             "name": "Thrombospondin type-1 (TSP1) repeat",
#             "source_database": "interpro",
#             "type": "repeat"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 79,
#                                 "representative": false,
#                                 "start": 22
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 134,
#                                 "representative": false,
#                                 "start": 81
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 617,
#                                 "representative": false,
#                                 "start": 565
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR001862",
#             "go_terms": [
#                 {
#                     "category": {
#                         "code": "P",
#                         "name": "biological_process"
#                     },
#                     "identifier": "GO:0006955",
#                     "name": "immune response"
#                 },
#                 {
#                     "category": {
#                         "code": "C",
#                         "name": "cellular_component"
#                     },
#                     "identifier": "GO:0005579",
#                     "name": "membrane attack complex"
#                 }
#             ],
#             "integrated": null,
#             "member_databases": {
#                 "prints": {
#                     "PR00764": "COMPLEMENTC9"
#                 }
#             },
#             "name": "Membrane attack complex component/perforin/complement C9",
#             "source_database": "interpro",
#             "type": "family"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 117,
#                                 "representative": false,
#                                 "start": 101
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 164,
#                                 "representative": false,
#                                 "start": 144
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 365,
#                                 "representative": false,
#                                 "start": 343
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 490,
#                                 "representative": false,
#                                 "start": 471
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 519,
#                                 "representative": false,
#                                 "start": 500
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 543,
#                                 "representative": false,
#                                 "start": 523
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR002172",
#             "go_terms": [
#                 {
#                     "category": {
#                         "code": "F",
#                         "name": "molecular_function"
#                     },
#                     "identifier": "GO:0005515",
#                     "name": "protein binding"
#                 }
#             ],
#             "integrated": null,
#             "member_databases": {
#                 "cdd": {
#                     "cd00112": "LDLa"
#                 },
#                 "pfam": {
#                     "PF00057": "Low-density lipoprotein receptor domain class A"
#                 },
#                 "prints": {
#                     "PR00261": "LDLRECEPTOR"
#                 },
#                 "profile": {
#                     "PS50068": "LDL-receptor class A (LDLRA) domain profile"
#                 },
#                 "smart": {
#                     "SM00192": "Low-density lipoprotein receptor domain class A"
#                 }
#             },
#             "name": "Low-density lipoprotein (LDL) receptor class A repeat",
#             "source_database": "interpro",
#             "type": "repeat"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 175,
#                                 "representative": false,
#                                 "start": 139
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR002350",
#             "go_terms": [
#                 {
#                     "category": {
#                         "code": "F",
#                         "name": "molecular_function"
#                     },
#                     "identifier": "GO:0005515",
#                     "name": "protein binding"
#                 }
#             ],
#             "integrated": null,
#             "member_databases": {
#                 "pfam": {
#                     "PF00050": "Kazal-type serine protease inhibitor domain",
#                     "PF07648": "Kazal-type serine protease inhibitor domain"
#                 },
#                 "profile": {
#                     "PS51465": "Kazal domain profile"
#                 },
#                 "prosite": {
#                     "PS00282": "Kazal serine protease inhibitors family signature"
#                 },
#                 "smart": {
#                     "SM00280": "Kazal type serine protease inhibitors"
#                 }
#             },
#             "name": "Kazal domain",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 839,
#                                 "representative": false,
#                                 "start": 785
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR003884",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "smart": {
#                     "SM00057": "factor I membrane attack complex"
#                 }
#             },
#             "name": "Factor I / membrane attack complex",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 839,
#                                 "representative": false,
#                                 "start": 767
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 934,
#                                 "representative": false,
#                                 "start": 861
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR020863",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "prosite": {
#                     "PS00279": "Membrane attack complex/perforin (MACPF) domain signature"
#                 }
#             },
#             "name": "Membrane attack complex component/perforin domain, conserved site",
#             "source_database": "interpro",
#             "type": "conserved_site"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 365,
#                                 "representative": false,
#                                 "start": 354
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR020864",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "pfam": {
#                     "PF01823": "MAC/Perforin domain"
#                 },
#                 "profile": {
#                     "PS51412": "Membrane attack complex/perforin (MACPF) domain profile"
#                 },
#                 "smart": {
#                     "SM00457": "membrane-attack complex / perforin"
#                 }
#             },
#             "name": "Membrane attack complex component/perforin (MACPF) domain",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 522,
#                                 "representative": false,
#                                 "start": 176
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR023415",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "prosite": {
#                     "PS01209": "LDL-receptor class A (LDLRA) domain signature"
#                 }
#             },
#             "name": "Low-density lipoprotein (LDL) receptor class A, conserved site",
#             "source_database": "interpro",
#             "type": "conserved_site"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 173,
#                                 "representative": false,
#                                 "start": 151
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR035976",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "ssf": {
#                     "SSF57535": "Complement control module/SCR domain"
#                 }
#             },
#             "name": "Sushi/SCR/CCP superfamily",
#             "source_database": "interpro",
#             "type": "homologous_superfamily"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 754,
#                                 "representative": false,
#                                 "start": 644
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR036055",
#             "go_terms": [
#                 {
#                     "category": {
#                         "code": "F",
#                         "name": "molecular_function"
#                     },
#                     "identifier": "GO:0005515",
#                     "name": "protein binding"
#                 }
#             ],
#             "integrated": null,
#             "member_databases": {
#                 "cathgene3d": {
#                     "G3DSA:4.10.400.10": "Low-density Lipoprotein Receptor"
#                 },
#                 "ssf": {
#                     "SSF57424": "LDL receptor-like module"
#                 }
#             },
#             "name": "LDL receptor-like superfamily",
#             "source_database": "interpro",
#             "type": "homologous_superfamily"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 180,
#                                 "representative": false,
#                                 "start": 138
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR036383",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "cathgene3d": {
#                     "G3DSA:2.20.100.10": "Thrombospondin type-1 (TSP1) repeat"
#                 },
#                 "ssf": {
#                     "SSF82895": "TSP-1 type 1 repeat"
#                 }
#             },
#             "name": "Thrombospondin type-1 (TSP1) repeat superfamily",
#             "source_database": "interpro",
#             "type": "homologous_superfamily"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 79,
#                                 "representative": false,
#                                 "start": 22
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 128,
#                                 "representative": false,
#                                 "start": 80
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     },
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 614,
#                                 "representative": false,
#                                 "start": 563
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR048828",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "pfam": {
#                     "PF21288": "Complement component C6, KAZAL domain"
#                 }
#             },
#             "name": "Complement component C6, KAZAL domain",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 838,
#                                 "representative": false,
#                                 "start": 785
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     },
#     {
#         "metadata": {
#             "accession": "IPR048831",
#             "go_terms": null,
#             "integrated": null,
#             "member_databases": {
#                 "pfam": {
#                     "PF21195": "Complement components C8A/B/C6, EGF-like domain"
#                 }
#             },
#             "name": "Complement components C8A/B/C6, EGF-like domain",
#             "source_database": "interpro",
#             "type": "domain"
#         },
#         "proteins": [
#             {
#                 "accession": "p13671",
#                 "entry_protein_locations": [
#                     {
#                         "fragments": [
#                             {
#                                 "dc-status": "CONTINUOUS",
#                                 "end": 554,
#                                 "representative": false,
#                                 "start": 526
#                             }
#                         ],
#                         "model": null,
#                         "score": null
#                     }
#                 ],
#                 "organism": "9606",
#                 "protein_length": 934,
#                 "source_database": "reviewed"
#             }
#         ]
#     }
# ]

# %%
domain_stuff = [x for x in json_file if x["metadata"]["type"] == "domain"]
domain_boundaries = {x["metadata"]["accession"]: x["proteins"][0] for x in domain_stuff}
print(domain_boundaries)
# Out:
# {'IPR000436': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 642, 'end': 701, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}, {'fragments': [{'start': 702, 'end': 763, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}, 'IPR002350': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 785, 'end': 839, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}, 'IPR003884': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 767, 'end': 839, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}, {'fragments': [{'start': 861, 'end': 934, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}, 'IPR020864': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 176, 'end': 522, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}, 'IPR048828': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 785, 'end': 838, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}, 'IPR048831': {'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 526, 'end': 554, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}}

# %%
print(json.dumps(domain_boundaries, indent=4, sort_keys=True))
# Out:
# {
#     "IPR002223": {
#         "accession": "p05067",
#         "entry_protein_locations": [
#             {
#                 "fragments": [
#                     {
#                         "dc-status": "CONTINUOUS",
#                         "end": 342,
#                         "representative": false,
#                         "start": 288
#                     }
#                 ],
#                 "model": null,
#                 "score": null
#             }
#         ],
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "IPR003599": {
#         "accession": "p05067",
#         "entry_protein_locations": null,
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "IPR007110": {
#         "accession": "p05067",
#         "entry_protein_locations": null,
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "IPR008154": {
#         "accession": "p05067",
#         "entry_protein_locations": [
#             {
#                 "fragments": [
#                     {
#                         "dc-status": "CONTINUOUS",
#                         "end": 189,
#                         "representative": false,
#                         "start": 24
#                     }
#                 ],
#                 "model": null,
#                 "score": null
#             }
#         ],
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "IPR011178": {
#         "accession": "p05067",
#         "entry_protein_locations": [
#             {
#                 "fragments": [
#                     {
#                         "dc-status": "CONTINUOUS",
#                         "end": 188,
#                         "representative": false,
#                         "start": 132
#                     }
#                 ],
#                 "model": null,
#                 "score": null
#             }
#         ],
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "cd00099": {
#         "accession": "p05067",
#         "entry_protein_locations": null,
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "cd21707": {
#         "accession": "p05067",
#         "entry_protein_locations": null,
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     },
#     "cd22607": {
#         "accession": "p05067",
#         "entry_protein_locations": [
#             {
#                 "fragments": [
#                     {
#                         "dc-status": "CONTINUOUS",
#                         "end": 341,
#                         "representative": false,
#                         "start": 294
#                     }
#                 ],
#                 "model": "cd22607",
#                 "representative": false,
#                 "score": 1.26467e-31
#             }
#         ],
#         "organism": "9606",
#         "protein_length": 770,
#         "source_database": "reviewed"
#     }
# }

# %%
for k, v in domain_boundaries.items():
    if v["entry_protein_locations"] is not None:
        print(k, v["entry_protein_locations"][0]["fragments"][0]["start"], v["entry_protein_locations"][-1]["fragments"][0]["end"] )
# Out:
# cd22607 294 341
# IPR002223 288 342
# IPR008154 24 189
# IPR011178 132 188

# %%
for x in domain_stuff:
    print(x["metadata"])
    print(x["proteins"])
# Out:
# {'accession': 'IPR000436', 'name': 'Sushi/SCR/CCP domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'profile': {'PS50923': 'Sushi/CCP/SCR domain profile'}, 'cdd': {'cd00033': 'Complement control protein (CCP) modules (aka short consensus repeats SCRs or SUSHI repeats) have been identified in several proteins of the complement system'}, 'smart': {'SM00032': 'Domain abundant in complement control proteins; SUSHI repeat; short complement-like repeat (SCR)'}, 'pfam': {'PF00084': 'Sushi repeat (SCR repeat)'}}, 'go_terms': None}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 642, 'end': 701, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}, {'fragments': [{'start': 702, 'end': 763, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]
# {'accession': 'IPR002350', 'name': 'Kazal domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'pfam': {'PF07648': 'Kazal-type serine protease inhibitor domain', 'PF00050': 'Kazal-type serine protease inhibitor domain'}, 'smart': {'SM00280': 'Kazal type serine protease inhibitors'}, 'profile': {'PS51465': 'Kazal domain profile'}, 'prosite': {'PS00282': 'Kazal serine protease inhibitors family signature'}}, 'go_terms': [{'identifier': 'GO:0005515', 'name': 'protein binding', 'category': {'code': 'F', 'name': 'molecular_function'}}]}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 785, 'end': 839, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]
# {'accession': 'IPR003884', 'name': 'Factor I / membrane attack complex', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'smart': {'SM00057': 'factor I membrane attack complex'}}, 'go_terms': None}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 767, 'end': 839, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}, {'fragments': [{'start': 861, 'end': 934, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]
# {'accession': 'IPR020864', 'name': 'Membrane attack complex component/perforin (MACPF) domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'profile': {'PS51412': 'Membrane attack complex/perforin (MACPF) domain profile'}, 'pfam': {'PF01823': 'MAC/Perforin domain'}, 'smart': {'SM00457': 'membrane-attack complex / perforin'}}, 'go_terms': None}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 176, 'end': 522, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]
# {'accession': 'IPR048828', 'name': 'Complement component C6, KAZAL domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'pfam': {'PF21288': 'Complement component C6, KAZAL domain'}}, 'go_terms': None}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 785, 'end': 838, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]
# {'accession': 'IPR048831', 'name': 'Complement components C8A/B/C6, EGF-like domain', 'source_database': 'interpro', 'type': 'domain', 'integrated': None, 'member_databases': {'pfam': {'PF21195': 'Complement components C8A/B/C6, EGF-like domain'}}, 'go_terms': None}
# [{'accession': 'p13671', 'protein_length': 934, 'source_database': 'reviewed', 'organism': '9606', 'entry_protein_locations': [{'fragments': [{'start': 526, 'end': 554, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]}]

# %%
print(domain_stuff[3]["proteins"][0]["entry_protein_locations"])
for x in domain_stuff[3]["proteins"][0]["entry_protein_locations"]:
    print(x["fragments"])
# Out:
# [{'fragments': [{'start': 176, 'end': 522, 'dc-status': 'CONTINUOUS', 'representative': False}], 'model': None, 'score': None}]
# [{'start': 176, 'end': 522, 'dc-status': 'CONTINUOUS', 'representative': False}]

# %%
interpro_data = pd.DataFrame([x['metadata'] for x in domain_stuff])
other_data = pd.DataFrame([x['proteins'][0] for x in domain_stuff])
print(other_data)
# Out:
#   accession  protein_length source_database organism  \
# 0    p05067             770        reviewed     9606
# 1    p05067             770        reviewed     9606
# 2    p05067             770        reviewed     9606
# 3    p05067             770        reviewed     9606
# 4    p05067             770        reviewed     9606
# 5    p05067             770        reviewed     9606
# 6    p05067             770        reviewed     9606
# 7    p05067             770        reviewed     9606
#
#                              entry_protein_locations
# 0                                               None
# 1                                               None
# 2  [{'fragments': [{'start': 294, 'end': 341, 'dc...
# 3  [{'fragments': [{'start': 288, 'end': 342, 'dc...
# 4                                               None
# 5                                               None
# 6  [{'fragments': [{'start': 24, 'end': 189, 'dc-...
# 7  [{'fragments': [{'start': 132, 'end': 188, 'dc...
